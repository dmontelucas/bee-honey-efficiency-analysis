# %%
import pandas as pd

df = pd.read_csv("../data/processed/honey_pollen_efficiency_clean.csv")
df.head()
# Out:
#           hive_id trial_id  colony_strength      pollen_feed_1_dates  \
# 0  LAO BRO 20.2.1   20.2.1             80000  01-09-2025\n02-09-2025
# 1  LAO BRO 20.2.2   20.2.2             80000  01-09-2025\n02-09-2025
# 2  LAO BRO 20.2.3   20.2.3            120000  01-09-2025\n02-09-2025
# 3  LAO BRO 20.2.4   20.2.4            120000  01-09-2025\n02-09-2025
# 4  LAO BRO 20.2.5   20.2.5            120000  01-09-2025\n02-09-2025
#
#       pollen_feed_2_dates     pollen_feed_3_dates     pollen_feed_4_dates  \
# 0  04-09-2025\n05-09-2025  08-09-2025\n09-09-2025  11-09-2025\n12-09-2025
# 1  04-09-2025\n05-09-2025  08-09-2025\n09-09-2025  11-09-2025\n12-09-2025
# 2  04-09-2025\n05-09-2025  08-09-2025\n09-09-2025  11-09-2025\n12-09-2025
# 3  04-09-2025\n05-09-2025  08-09-2025\n09-09-2025  11-09-2025\n12-09-2025
# 4  04-09-2025\n05-09-2025  08-09-2025\n09-09-2025  11-09-2025\n12-09-2025
#
#    pollen_feed_1  pollen_feed_2  pollen_feed_3  ...  collection_3_output  \
# 0            600            600            600  ...             202000.0
# 1            600            600            600  ...             187000.0
# 2            600            600            600  ...             367000.0
# 3            600            600            600  ...             295000.0
# 4            600            600            600  ...             390000.0
#
#   collection_4_output time_hours pollen_input_g honey_output_g  location  \
# 0            218000.0         48         2400.0      1065500.0       22C
# 1            393000.0         48         2400.0      1155000.0       22C
# 2            350000.0         48         2400.0      1917000.0       22A
# 3            213000.0         48         2400.0      1136000.0       18B
# 4            200000.0         48         2400.0      1750000.0       18B
#
#    humidity_pct  temperature_c  efficiency  honey_per_hour
# 0            75             27  443.958333    22197.916667
# 1            75             27  481.250000    24062.500000
# 2            75             27  798.750000    39937.500000
# 3            75             27  473.333333    23666.666667
# 4            75             27  729.166667    36458.333333
#
# [5 rows x 27 columns]

# %%
df.describe()
# Out:
#        colony_strength   pollen_feed_1  pollen_feed_2  pollen_feed_3  \
# count        107.000000     107.000000     107.000000     107.000000
# mean      110175.700935     586.168224     586.168224     586.168224
# std        29975.681468     105.809056     105.809056     105.809056
# min          100.000000      60.000000      60.000000      60.000000
# 25%       100000.000000     600.000000     600.000000     600.000000
# 50%       107000.000000     600.000000     600.000000     600.000000
# 75%       120000.000000     600.000000     600.000000     600.000000
# max       160000.000000     800.000000     800.000000     800.000000
#
#        pollen_feed_4  collection_1_output  collection_2_output  \
# count     107.000000         1.070000e+02           107.000000
# mean      586.168224         4.412150e+05        452953.271028
# std       105.809056         1.953737e+05        186376.046784
# min        60.000000         2.000000e+03          2500.000000
# 25%       600.000000         3.325000e+05        338500.000000
# 50%       600.000000         4.400000e+05        455000.000000
# 75%       600.000000         5.550000e+05        590000.000000
# max       800.000000         1.135000e+06        895000.000000
#
#        collection_3_output  collection_4_output  time_hours  pollen_input_g  \
# count           107.000000           107.000000       107.0      107.000000
# mean         320471.962617        317623.364486        48.0     2344.672897
# std          121441.068707        141942.850298         0.0      423.236224
# min            2500.000000          2700.000000        48.0      240.000000
# 25%          234000.000000        220000.000000        48.0     2400.000000
# 50%          330000.000000        297000.000000        48.0     2400.000000
# 75%          417000.000000        399000.000000        48.0     2400.000000
# max          585000.000000        725000.000000        48.0     3200.000000
#
#        honey_output_g  humidity_pct  temperature_c   efficiency  \
# count    1.070000e+02         107.0          107.0   107.000000
# mean     1.532264e+06          75.0           27.0   643.176372
# std      5.270640e+05           0.0            0.0   204.389399
# min      9.700000e+03          75.0           27.0    40.416667
# 25%      1.228000e+06          75.0           27.0   516.041667
# 50%      1.615000e+06          75.0           27.0   659.166667
# 75%      1.884000e+06          75.0           27.0   772.500000
# max      2.770000e+06          75.0           27.0  1154.166667
#
#        honey_per_hour
# count      107.000000
# mean     31922.157321
# std      10980.499410
# min        202.083333
# 25%      25583.333333
# 50%      33645.833333
# 75%      39250.000000
# max      57708.333333

# %%
import matplotlib.pyplot as plt

plt.hist(df["efficiency"], bins=20)
plt.xlabel("Honey per gram of pollen")
plt.ylabel("Number of trials")
plt.title("Distribution of Honey Production Efficiency")
plt.show()

# %%
plt.scatter(df["pollen_input_g"], df["honey_output_g"])
plt.xlabel("Pollen Input (g)")
plt.ylabel("Honey Output (g)")
plt.title("Pollen Input vs Honey Output")
plt.show()

# %%
df.groupby("hive_id")["efficiency"].mean().sort_values(ascending=False)
# Out:
# hive_id
# TML BRO 16.2.2    1154.166667
# TML BRO 15.5.5    1070.833333
# TML BRO 16.2.1    1052.083333
# TML BRO 16.1.4    1025.000000
# TML BRO 15.6.4    1006.666667
#                      ...
# TML AMP 15.3.1     207.916667
# TML AMP 15.2.2     190.000000
# TML AMP 15.2.1     137.708333
# LAO BRO 20.5.5     106.250000
# LAO BRO 20.4.9      40.416667
# Name: efficiency, Length: 107, dtype: float64

# %% [markdown]
# efficiency vs input analysis: scatterplot, bucketed mean line, sample-size bar chart.(below)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(df["pollen_input_g"], df["efficiency"])
plt.xlabel("Pollen input (g)")
plt.ylabel("Efficiency")
plt.title("Efficiency vs Input (All Trials)")
plt.show()

# %%
import os
os.makedirs("../reports/figures", exist_ok=True)


bucket_df = (
    df.assign(input_bucket=(df["pollen_input_g"] // 500) * 500)
      .groupby("input_bucket")
      .agg(
          avg_efficiency=("efficiency", "mean"),
          n_trials=("efficiency", "count")
      )
      .reset_index()
)

plt.figure()
plt.plot(bucket_df["input_bucket"], bucket_df["avg_efficiency"], marker="o")
plt.xlabel("Input bucket (g)")
plt.ylabel("Average efficiency")
plt.title("Average Efficiency by Input Bucket")
plt.savefig("../reports/figures/efficiency_by_bucket.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(
    bucket_df["input_bucket"].astype(str),
    bucket_df["n_trials"]
)
plt.xlabel("Input bucket (g)")
plt.ylabel("Number of trials")
plt.title("Trial Count per Input Bucket")
plt.show()

# %%
print(bucket_df.shape)
bucket_df.head()
bucket_df.dtypes
# Out:
# (5, 3)
# input_bucket      float64
# avg_efficiency    float64
# n_trials            int64
# dtype: object

# %%
import numpy as np
os.makedirs("../reports/figures", exist_ok=True)

x = df["pollen_input_g"]
y = df["efficiency"]

z = np.polyfit(x, y, 2)
p = np.poly1d(z)

x_sorted = np.sort(x)
plt.figure()
plt.scatter(x, y, alpha=0.3)
plt.plot(x_sorted, p(x_sorted))
plt.xlabel("Pollen input (g)")
plt.ylabel("Efficiency")
plt.title("Efficiency vs Input with Smoothed Trend")
plt.savefig("../reports/figures/efficiency_vs_input_smooth_trend.png", dpi=300, bbox_inches="tight")
plt.show()
