# %%
import pandas as pd
import statsmodels.api as sm

df = pd.read_csv("../data/processed/honey_pollen_efficiency_clean.csv")
# Out:
# /home/ldmonte/workspace/SQLite/Bee_trials/bee-honey-efficiency-analysis/venv/lib/python3.12/site-packages/numpy/_core/getlimits.py:552: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %%
X = df[["pollen_input_g", "temperature_c", "humidity_pct", "colony_strength "]]
y = df["honey_output_g"]

X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         honey_output_g   R-squared:                       0.303
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     22.65
# Date:                Wed, 03 Dec 2025   Prob (F-statistic):           6.81e-09
# Time:                        15:28:23   Log-Likelihood:                -1541.7
# No. Observations:                 107   AIC:                             3089.
# Df Residuals:                     104   BIC:                             3097.
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# pollen_input_g     371.1583    172.391      2.153      0.034      29.300     713.017
# temperature_c      495.4470   1060.519      0.467      0.641   -1607.603    2598.497
# humidity_pct      1376.2416   2945.887      0.467      0.641   -4465.563    7218.046
# colony_strength      4.9505      2.434      2.034      0.045       0.124       9.777
# ==============================================================================
# Omnibus:                        3.069   Durbin-Watson:                   0.974
# Prob(Omnibus):                  0.216   Jarque-Bera (JB):                2.983
# Skew:                          -0.120   Prob(JB):                        0.225
# Kurtosis:                       3.782   Cond. No.                     1.93e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.76e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
df.columns.tolist()
# Out:
# ['hive_id',
#  'trial_id',
#  'colony_strength ',
#  'pollen_feed_1_dates',
#  'pollen_feed_2_dates',
#  'pollen_feed_3_dates',
#  'pollen_feed_4_dates',
#  'pollen_feed_1',
#  'pollen_feed_2',
#  'pollen_feed_3',
#  'pollen_feed_4',
#  'collection_1_date',
#  'collection_2_date',
#  'collection_3_date',
#  'collection_4_date',
#  'collection_1_output',
#  'collection_2_output',
#  'collection_3_output',
#  'collection_4_output',
#  'time_hours',
#  'pollen_input_g',
#  'honey_output_g',
#  'location',
#  'humidity_pct',
#  'temperature_c',
#  'efficiency',
#  'honey_per_hour']
